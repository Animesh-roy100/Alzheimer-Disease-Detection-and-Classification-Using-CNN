# %%
import tensorflow as tf
from tensorflow import keras 
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as img
# %matplotlib inline
import tensorflow.keras.backend as K
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing import image
from pylab import imread,subplot,imshow,show
import cv2
import os

# %%
train = ImageDataGenerator(rescale=1./255)
test =  ImageDataGenerator(rescale=1./255)
val =  ImageDataGenerator(rescale=1./255)

# %%
train='dataset/train/'

# %%
train_data = tf.keras.preprocessing.image_dataset_from_directory(
    train,
    validation_split=0.2,
    image_size=(224,224),
    batch_size=32,
    subset='training',
    seed=1000 )
# Out:
# Found 5121 files belonging to 4 classes.
# Using 4097 files for training.

# %%
val='dataset/train/'

# %%
val_data = tf.keras.preprocessing.image_dataset_from_directory(
    val,
    validation_split=0.2,
    image_size=(224,224),
    batch_size=32,
    subset='validation',
    seed=1000
    )
# Out:
# Found 5121 files belonging to 4 classes.
# Using 1024 files for validation.

# %%
test='dataset/test/'

# %%
test_data=tf.keras.preprocessing.image_dataset_from_directory(
    test,
    image_size=(224,224),
    batch_size=32,
    seed=1000
    )
# Out:
# Found 1279 files belonging to 4 classes.

# %%
class_names = ['MildDementia', 'ModerateDementia', 'NonDementia', 'VeryMildDementia']

# %%
train_data.class_names = class_names
val_data.class_names = class_names

# %%
print(val_data)
# Out:
# <BatchDataset shapes: ((None, 224, 224, 3), (None,)), types: (tf.float32, tf.int32)>

# %%
plt.figure(figsize=(10, 10))
for images, labels in train_data.take(1):
    for i in range(6):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))
        plt.title(train_data.class_names[labels[i]])
        plt.axis("off")

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPooling2D,Input
from tensorflow.keras.layers import Dense

# %%
model=Sequential()

model.add(Conv2D(16,(3,3), activation='relu', input_shape=(224,224,3)))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(32,(3,3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(32,(3,3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(32,(3,3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Flatten())
model.add(Dense(30,activation='relu'))
model.add(Dense(10,activation='relu'))
model.add(Dense(100,activation='relu'))
model.add(Dense(133,activation='relu'))
model.add(Dense(4,activation='softmax'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 222, 222, 16)      448
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 111, 111, 16)      0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 109, 109, 32)      4640
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 54, 54, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 52, 52, 32)        9248
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 26, 26, 32)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 24, 24, 32)        9248
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 12, 12, 32)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 4608)              0
# _________________________________________________________________
# dense (Dense)                (None, 30)                138270
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                310
# _________________________________________________________________
# dense_2 (Dense)              (None, 100)               1100
# _________________________________________________________________
# dense_3 (Dense)              (None, 133)               13433
# _________________________________________________________________
# dense_4 (Dense)              (None, 4)                 536
# =================================================================
# Total params: 177,233
# Trainable params: 177,233
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer = tf.keras.optimizers.Adam(1e-4), loss="sparse_categorical_crossentropy", metrics=["accuracy"])

# %%
history = model.fit(train_data, validation_data=val_data, epochs=50)
# Out:
# Epoch 1/50
# 129/129 [==============================] - 14s 70ms/step - loss: 1.0467 - accuracy: 0.5062 - val_loss: 0.9013 - val_accuracy: 0.5498
# Epoch 2/50
# 129/129 [==============================] - 10s 78ms/step - loss: 0.9111 - accuracy: 0.5633 - val_loss: 1.1641 - val_accuracy: 0.5176
# Epoch 3/50
# 129/129 [==============================] - 12s 88ms/step - loss: 0.8899 - accuracy: 0.5926 - val_loss: 0.8099 - val_accuracy: 0.6230
# Epoch 4/50
# 129/129 [==============================] - 11s 85ms/step - loss: 0.8047 - accuracy: 0.6327 - val_loss: 0.7782 - val_accuracy: 0.6279
# Epoch 5/50
# 129/129 [==============================] - 9s 69ms/step - loss: 0.7064 - accuracy: 0.6817 - val_loss: 0.7994 - val_accuracy: 0.6289
# Epoch 6/50
# 129/129 [==============================] - 9s 66ms/step - loss: 0.6197 - accuracy: 0.7352 - val_loss: 0.7781 - val_accuracy: 0.6621
# Epoch 7/50
# 129/129 [==============================] - 9s 68ms/step - loss: 0.5160 - accuracy: 0.7879 - val_loss: 0.5770 - val_accuracy: 0.7607
# Epoch 8/50
# 129/129 [==============================] - 9s 71ms/step - loss: 0.3838 - accuracy: 0.8501 - val_loss: 0.4315 - val_accuracy: 0.8301
# Epoch 9/50
# 129/129 [==============================] - 9s 72ms/step - loss: 0.2836 - accuracy: 0.8950 - val_loss: 0.4415 - val_accuracy: 0.8291
# Epoch 10/50
# 129/129 [==============================] - 9s 68ms/step - loss: 0.1940 - accuracy: 0.9292 - val_loss: 0.4425 - val_accuracy: 0.8398
# Epoch 11/50
# 129/129 [==============================] - 9s 66ms/step - loss: 0.1393 - accuracy: 0.9563 - val_loss: 0.4110 - val_accuracy: 0.8477
# Epoch 12/50
# 129/129 [==============================] - 8s 64ms/step - loss: 0.0845 - accuracy: 0.9763 - val_loss: 0.2357 - val_accuracy: 0.9189
# Epoch 13/50
# 129/129 [==============================] - 8s 64ms/step - loss: 0.1031 - accuracy: 0.9712 - val_loss: 0.3455 - val_accuracy: 0.8828
# Epoch 14/50
# 129/129 [==============================] - 8s 64ms/step - loss: 0.0743 - accuracy: 0.9761 - val_loss: 0.2452 - val_accuracy: 0.9199
# Epoch 15/50
# 129/129 [==============================] - 9s 69ms/step - loss: 0.0311 - accuracy: 0.9941 - val_loss: 0.1634 - val_accuracy: 0.9453
# Epoch 16/50
# 129/129 [==============================] - 9s 68ms/step - loss: 0.0155 - accuracy: 0.9980 - val_loss: 0.1703 - val_accuracy: 0.9473
# Epoch 17/50
# 129/129 [==============================] - 9s 66ms/step - loss: 0.0143 - accuracy: 0.9988 - val_loss: 0.1606 - val_accuracy: 0.9463
# Epoch 18/50
# 129/129 [==============================] - 9s 72ms/step - loss: 0.0074 - accuracy: 1.0000 - val_loss: 0.1632 - val_accuracy: 0.9443
# Epoch 19/50
# 129/129 [==============================] - 9s 70ms/step - loss: 0.0052 - accuracy: 1.0000 - val_loss: 0.2079 - val_accuracy: 0.9297
# Epoch 20/50
# 129/129 [==============================] - 10s 80ms/step - loss: 0.0053 - accuracy: 1.0000 - val_loss: 0.1758 - val_accuracy: 0.9453
# Epoch 21/50
# 129/129 [==============================] - 9s 68ms/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 0.1431 - val_accuracy: 0.9609
# Epoch 22/50
# 129/129 [==============================] - 9s 65ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.1368 - val_accuracy: 0.9629
# Epoch 23/50
# 129/129 [==============================] - 9s 66ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.1382 - val_accuracy: 0.9609
# Epoch 24/50
# 129/129 [==============================] - 9s 65ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.1576 - val_accuracy: 0.9561
# Epoch 25/50
# 129/129 [==============================] - 9s 70ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.1380 - val_accuracy: 0.9648
# Epoch 26/50
# 129/129 [==============================] - 9s 69ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1424 - val_accuracy: 0.9590
# Epoch 27/50
# 129/129 [==============================] - 9s 69ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1409 - val_accuracy: 0.9619
# Epoch 28/50
# 129/129 [==============================] - 9s 68ms/step - loss: 9.1259e-04 - accuracy: 1.0000 - val_loss: 0.1415 - val_accuracy: 0.9619
# Epoch 29/50
# 129/129 [==============================] - 9s 72ms/step - loss: 8.3448e-04 - accuracy: 1.0000 - val_loss: 0.1407 - val_accuracy: 0.9629
# Epoch 30/50
# 129/129 [==============================] - 9s 70ms/step - loss: 7.4630e-04 - accuracy: 1.0000 - val_loss: 0.1414 - val_accuracy: 0.9658
# Epoch 31/50
# 129/129 [==============================] - 9s 67ms/step - loss: 6.3180e-04 - accuracy: 1.0000 - val_loss: 0.1396 - val_accuracy: 0.9648
# Epoch 32/50
# 129/129 [==============================] - 9s 68ms/step - loss: 5.6645e-04 - accuracy: 1.0000 - val_loss: 0.1400 - val_accuracy: 0.9639
# Epoch 33/50
# 129/129 [==============================] - 9s 66ms/step - loss: 5.3013e-04 - accuracy: 1.0000 - val_loss: 0.1434 - val_accuracy: 0.9619
# Epoch 34/50
# 129/129 [==============================] - 9s 68ms/step - loss: 4.7145e-04 - accuracy: 1.0000 - val_loss: 0.1404 - val_accuracy: 0.9639
# Epoch 35/50
# 129/129 [==============================] - 10s 80ms/step - loss: 4.0467e-04 - accuracy: 1.0000 - val_loss: 0.1395 - val_accuracy: 0.9648
# Epoch 36/50
# 129/129 [==============================] - 11s 82ms/step - loss: 3.5860e-04 - accuracy: 1.0000 - val_loss: 0.1440 - val_accuracy: 0.9629
# Epoch 37/50
# 129/129 [==============================] - 10s 73ms/step - loss: 3.3264e-04 - accuracy: 1.0000 - val_loss: 0.1426 - val_accuracy: 0.9648
# Epoch 38/50
# 129/129 [==============================] - 8s 63ms/step - loss: 3.0245e-04 - accuracy: 1.0000 - val_loss: 0.1449 - val_accuracy: 0.9629
# Epoch 39/50
# 129/129 [==============================] - 9s 69ms/step - loss: 2.7957e-04 - accuracy: 1.0000 - val_loss: 0.1420 - val_accuracy: 0.9619
# Epoch 40/50
# 129/129 [==============================] - 9s 68ms/step - loss: 2.4028e-04 - accuracy: 1.0000 - val_loss: 0.1462 - val_accuracy: 0.9629
# Epoch 41/50
# 129/129 [==============================] - 9s 68ms/step - loss: 2.2878e-04 - accuracy: 1.0000 - val_loss: 0.1437 - val_accuracy: 0.9639
# Epoch 42/50
# 129/129 [==============================] - 9s 69ms/step - loss: 2.0279e-04 - accuracy: 1.0000 - val_loss: 0.1487 - val_accuracy: 0.9648
# Epoch 43/50
# 129/129 [==============================] - 9s 69ms/step - loss: 2.0926e-04 - accuracy: 1.0000 - val_loss: 0.1462 - val_accuracy: 0.9639
# Epoch 44/50
# 129/129 [==============================] - 9s 68ms/step - loss: 1.6647e-04 - accuracy: 1.0000 - val_loss: 0.1445 - val_accuracy: 0.9648
# Epoch 45/50
# 129/129 [==============================] - 8s 62ms/step - loss: 1.5022e-04 - accuracy: 1.0000 - val_loss: 0.1528 - val_accuracy: 0.9648
# Epoch 46/50
# 129/129 [==============================] - 9s 68ms/step - loss: 1.6150e-04 - accuracy: 1.0000 - val_loss: 0.1443 - val_accuracy: 0.9629
# Epoch 47/50
# 129/129 [==============================] - 9s 68ms/step - loss: 1.2497e-04 - accuracy: 1.0000 - val_loss: 0.1468 - val_accuracy: 0.9658
# Epoch 48/50
# 129/129 [==============================] - 9s 68ms/step - loss: 1.1661e-04 - accuracy: 1.0000 - val_loss: 0.1454 - val_accuracy: 0.9668
# Epoch 49/50
# 129/129 [==============================] - 9s 69ms/step - loss: 1.0451e-04 - accuracy: 1.0000 - val_loss: 0.1453 - val_accuracy: 0.9629
# Epoch 50/50
# 129/129 [==============================] - 9s 70ms/step - loss: 9.6221e-05 - accuracy: 1.0000 - val_loss: 0.1484 - val_accuracy: 0.9658

# %%
model.save("weight.h5")

# %%
model.evaluate(val_data)
# Out:
# 32/32 [==============================] - 1s 29ms/step - loss: 0.1484 - accuracy: 0.9658
# [0.14839226007461548, 0.9658203125]

# %%
plt.plot(history.history['accuracy'])
plt.title('Train model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.title('Train Model loss')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.show()

# %%
plt.plot(history.history['val_accuracy'])
plt.title(' Val model Accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.show()

# %%
plt.plot(history.history['val_loss'])
plt.title(' Val Model Loss')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.show()

# %%
loss_train = history.history['loss']
loss_val = history.history['val_loss']
plt.plot(loss_train, 'g', label='Training loss')
plt.plot(loss_val, 'b', label='validation loss')
plt.title('Training and Validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
accuracy_train = history.history['accuracy']
accuracy_val = history.history['val_accuracy']
plt.plot(accuracy_train, 'g', label='Training accuracy')
plt.plot(accuracy_val, 'b', label='Validation accuracy')
plt.title('Training and Validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
class_names={0:"MildDementia", 1:"ModerateDementia", 2:"NonDementia", 3:"VeryMildDementia"}

# %%
for images, labels in val_data.take(1):
    for i in range(6):
        print("True_class:",val_data.class_names[labels[i]])
        x = image.img_to_array(images[i])
        x = np.expand_dims(x, axis=0)
        p=np.argmax(model.predict(x))
        if p==0:
            print("Predicted Image: Mild Dementia")
        elif p==1:
            print("Predicted Image: Moderate Dementia")
        elif p==2:
            print("Predicted Image: Non Dementia")
        else:
            print("Predicted Image: Very Mild Dementia")
        
        print("Predicted class:",p)
# Out:
# True_class: VeryMildDementia
# Predicted Image: Very Mild Dementia
# Predicted class: 3
# True_class: MildDementia
# Predicted Image: Mild Dementia
# Predicted class: 0
# True_class: NonDementia
# Predicted Image: Non Dementia
# Predicted class: 2
# True_class: VeryMildDementia
# Predicted Image: Very Mild Dementia
# Predicted class: 3
# True_class: MildDementia
# Predicted Image: Mild Dementia
# Predicted class: 0
# True_class: VeryMildDementia
# Predicted Image: Very Mild Dementia
# Predicted class: 3
